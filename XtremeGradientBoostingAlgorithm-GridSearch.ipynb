# %%
# !pip install xgboost

# %%
import xgboost

# %%
import pandas as pd

# %%
data=pd.read_csv("insurance_pre.csv")

# %%
data
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
data=pd.get_dummies(data,drop_first=True)

# %%
data
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=data[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=data[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
grid_param={"subsample":[0.75, 1],  "colsample_bytree":[0.75, 1], "max_depth":[2, 6]}

grid=GridSearchCV(XGBRegressor(),grid_param, refit=True, verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bi...ne,
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
# ...

# %%
results=grid.cv_results_

# %%
results
# Out:
# {'mean_fit_time': array([0.13749065, 0.14686337, 0.26873112, 0.24373336, 0.12811565,
#         0.12186666, 0.38747339, 0.35934954]),
#  'std_fit_time': array([0.02499847, 0.02538423, 0.03877714, 0.02119335, 0.01169225,
#         0.00624988, 0.02688039, 0.01976333]),
#  'mean_score_time': array([0.01249886, 0.00624938, 0.02187357, 0.02187357, 0.01874871,
#         0.00937519, 0.00312514, 0.0031249 ]),
#  'std_score_time': array([0.01169129, 0.0076539 , 0.0124994 , 0.01593289, 0.01169169,
#         0.00765481, 0.00625029, 0.00624981]),
#  'param_colsample_bytree': masked_array(data=[0.75, 0.75, 0.75, 0.75, 1, 1, 1, 1],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[2, 2, 6, 6, 2, 2, 6, 6],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
# ...

# %%
table=pd.DataFrame.from_dict(results)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.137491      0.024998         0.012499        0.011691
# 1       0.146863      0.025384         0.006249        0.007654
# 2       0.268731      0.038777         0.021874        0.012499
# 3       0.243733      0.021193         0.021874        0.015933
# 4       0.128116      0.011692         0.018749        0.011692
# 5       0.121867      0.006250         0.009375        0.007655
# 6       0.387473      0.026880         0.003125        0.006250
# 7       0.359350      0.019763         0.003125        0.006250
#
#   param_colsample_bytree param_max_depth param_subsample  \
# 0                   0.75               2            0.75
# 1                   0.75               2               1
# 2                   0.75               6            0.75
# 3                   0.75               6               1
# 4                      1               2            0.75
# ...

# %%
print("The Rscore value with Best Tuning Parameter{}:".format(grid.best_params_))
# Out:
# The Rscore value with Best Tuning Parameter{'colsample_bytree': 0.75, 'max_depth': 2, 'subsample': 1}:

# %%
ypred=grid.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
rscore=r2_score(y_test,ypred)

# %%
rscore
# Out:
# 0.8852434931478268

# %%
age_input=float(input("Age : "))
bmi_input=float(input("BMI : "))
child_input=int(input("Children: "))
sex_input=int(input("Sex Male 0 or 1 : "))
smoker_s_input=int(input("Smoker yes 0 or 1 : "))
# Out:
# Age : 30
# BMI : 30
# Children: 2
# Sex Male 0 or 1 : 1
# Smoker yes 0 or 1 : 1

# %%
future_predict=grid.predict([[age_input,bmi_input,child_input,sex_input,smoker_s_input]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4248\3409631229.py in <module>
# ----> 1 future_predict=grid.predict([[age_input,bmi_input,child_input,sex_input,smoker_s_input]])
#
# ~\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     111
#     112             # lambda, but not partial, allows help() to work with update_wrapper
# --> 113             out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)  # noqa
#     114         else:
#     115
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in predict(self, X)
#     519         """
#     520         check_is_fitted(self)
# --> 521         return self.best_estimator_.predict(X)
#     522
#     523     @available_if(_estimator_has("predict_proba"))
#
# ...

# %%
print("Future Prediction is{}: ".format(future_prediction))
# Out:
# Future Prediction is[[33.0, 31.0, 2, 1, 1]]:
